# %%
import pandas as pd


df = pd.read_csv("MOCK_DATA.csv")
# df.head(5)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1001 non-null   object
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   ip_address  1000 non-null   object
# dtypes: object(6)
# memory usage: 47.1+ KB

# %%
chunk_size = 10  # Process 100 rows at a time
for chunk in pd.read_csv("MOCK_DATA.csv", chunksize=chunk_size):
    print (chunk.head())
# Out:
#    id first_name   last_name                     email    gender  \
# 0   1        Eda     Fehners        efehners0@digg.com    Female
# 1   2      Scott       Ragat     sragat1@pinterest.com      Male
# 2   3        Alf       Letch  aletch2@wunderground.com      Male
# 3   4    Anthony  Gouldbourn  agouldbourn3@sina.com.cn      Male
# 4   5     Keslie      Vermer    kvermer4@google.com.au  Bigender
#
#        ip_address
# 0   61.143.244.49
# 1  33.121.236.101
# 2     205.5.2.255
# 3   91.131.147.29
# 4   148.50.87.205
#     id first_name   last_name                     email      gender  \
# 10  11        Ade     Pudsall        apudsalla@tamu.edu        Male
# 11  12     Ileana  MacIlhargy  imacilhargyb@spotify.com  Non-binary
# 12  13    Rinaldo      Redish     rredishc@addtoany.com        Male
# 13  14        Eva    Rowswell         erowswelld@go.com      Female
# 14  15      Emmey      Spargo        espargoe@about.com      Female
#
#          ip_address
# 10   100.221.231.10
# ...
